# %% [raw]
# {
#   "cells": [
#     {
#       "cell_type": "markdown",
#       "metadata": {},
#       "source": [
#         "# SE Series 3 — Exploration (stub)\n",
#         "\n",
#         "План ноутбука:\n",
#         "1. Setup\n",
#         "2. Загрузка MovieLens 100k\n",
#         "3. Content-based (TF-IDF)\n",
#         "4. Collaborative Filtering\n",
#         "5. Hybrid\n",
#         "6. Two-Tower\n",
#         "7. Evaluation + сравнение\n",
#         "8. Выводы\n"
#       ]
#     },
#     {
#       "cell_type": "code",
#       "execution_count": null,
#       "metadata": {},
#       "outputs": [],
#       "source": [
#         "from pathlib import Path\n",
#         "from se_series3.recsys.data_utils import download_movielens_100k, load_movielens_100k\n",
#         "\n",
#         "root = Path('se_series3') / 'data'\n",
#         "ml_root = download_movielens_100k(root)\n",
#         "data = load_movielens_100k(ml_root)\n",
#         "data.ratings.head()"
#       ]
#     }
#   ],
#   "metadata": {
#     "kernelspec": {
#       "display_name": "Python 3",
#       "language": "python",
#       "name": "python3"
#     },
#     "language_info": {
#       "name": "python",
#       "version": "3.10"
#     }
#   },
#   "nbformat": 4,
#   "nbformat_minor": 5
# }
